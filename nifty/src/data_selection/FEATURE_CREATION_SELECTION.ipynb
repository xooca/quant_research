# %%
import sys,os
project_path = "/content/drive/MyDrive/Work/quantitative_research/"
#database_path = "/content/drive/MyDrive/Work/trading_updated/database/production/banknifty_final.duckdb"

sys.path.append(project_path)

import data.utils.duckdb_utils as ddu
from featurewiz import featurewiz
import duckdb
import data.utils.data_utils as du
# Out:
# Imported 0.2.04 version. Select nrows to a small number when running on huge datasets.
# output = featurewiz(dataname, target, corr_limit=0.90, verbose=2, sep=',',
# 		header=0, test_data='',feature_engg='', category_encoders='',
# 		dask_xgboost_flag=False, nrows=None, skip_sulov=False)
# Create new features via 'feature_engg' flag : ['interactions','groupby','target']

# %%
# !ls
# Out:
# drive  libta.deb  sample_data  ta.deb

# %%
url = 'https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files'
ext = '0.4.0-oneiric1_amd64.deb -qO'
# !wget $url/libta-lib0_$ext libta.deb
# !wget $url/ta-lib0-dev_$ext ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
# Out:
# Selecting previously unselected package libta-lib0.
# (Reading database ... 128276 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# Selecting previously unselected package ta-lib0-dev.
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.0/272.0 KB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install duckdb==0.5.1
# !pip install hydra-core
# !pip install featurewiz
# !pip install xverse
# !pip install feature_engine
# !pip install shap-hypetune
# !pip install talib-binary
# !pip install -U git+https://github.com/twopirllc/pandas-ta
# !pip install ta
# !pip install mlxtend --upgrade --no-deps
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 53.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 KB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=7ff42cbd778d61fc21ef54025ee184a78b845abba5987cc3b144a827ff811234
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built antlr4-python3-runtime
# ...

# %%
master_config_path = "../../config/"
master_config_name = 'banknifty_master'
#db_conection = con
#feature_spec_name = 'data.feature_specs.feature_spec_final'
#feature_spec_name = 'data.feature_specs.label_creator_spec'
#train_feature_table="banknifty.train_feature_v2"
#train_feature_info_table="banknifty.train_feature_info_v2"
#database_path = "/content/drive/MyDrive/Work/data/banknifty 2.duckdb"
#database_path = "/content/drive/MyDrive/Work/trading_updated/database/development/banknifty.duckdb"
database_path = "/content/drive/Othercomputers/My Mac/google_drive/database/production/banknifty_final1.duckdb"
feature_spec_name = 'data.feature_specs.feature_spec_final_v2'
#db_connection = duckdb.connect(database=database_path , read_only=False)
data_suffix = 'improved_one'
train_feature_table = f'banknifty.train_feature_{data_suffix}'
train_feature_info_table = f'banknifty.train_feature_info_{data_suffix}'
train_feature_selection_table = f'banknifty.train_feature_selection_{data_suffix}'
train_training_info_table = f'banknifty.train_training_info_{data_suffix}'
train_tuning_info_table = f'banknifty.train_tuning_info_{data_suffix}'
ohlcraw_table = 'banknifty.ohlc_raw_data'

label_creation=False
techindicator1=False
techindicator2=False
techindicator3=False
time_splitter = False
column_unstable = False
update_unstable = False
load_tmp = True
#con = duckdb.connect(database=database_path , read_only=False)
filter_out_cols =["CMF_","RVGIs_","SSF_","STDEVALL","DPO_","ICS_","KAMA_","PDIST","RVGI_","PSAR","QS_"]
feature_selection_spec = "data.feature_selection_specs.feature_wiz_spec"

# %%
obj = du.execute_data_pipeline(master_config_path, 
                               master_config_name, 
                               db_conection=None, 
                               database_path=database_path,
                               feature_spec_name=feature_spec_name,
                               train_feature_table=train_feature_table,
                               train_feature_info_table=train_feature_info_table,
                               techindicator1=techindicator1,
                               techindicator2=techindicator2,
                               techindicator3=techindicator3,
                               time_splitter = time_splitter,
                               column_unstable = column_unstable,
                               label_creation=label_creation,
                               update_unstable=update_unstable,
                               load_tmp = load_tmp)
# Out:
# Feature spec file is data.feature_specs.label_creator_spec
# ['+master=banknifty_master'] ../../config/
# ['+data=data', '+model=pycaret_v4', '+common=common'] ../../config/banknifty/
# Shape of OHLC dataframe is (1193346, 6)
#             timestamp     ticker   open   high    low  close
# 0 2020-11-02 09:08:00  BANKNIFTY  24368  24368  24368  24368
# 1 2020-11-02 09:16:00  BANKNIFTY  24282  24328  24190  24284
# 2 2020-11-02 09:17:00  BANKNIFTY  24287  24289  24236  24251
# 3 2020-11-02 09:18:00  BANKNIFTY  24255  24263  24232  24249
# 4 2020-11-02 09:19:00  BANKNIFTY  24250  24259  24215  24217
# feature table is banknifty.train_feature_finale
# feature info table is banknifty.train_feature_info_finale
# Value of self.max_date_raw_table in banknifty.ohlc_raw_data is 2022-12-23 15:32:00
# Value of self.max_date_feature_table is 2022-12-23 15:32:00
# Value of self.min_date_feature_table is 2010-03-02 09:01:00
# Table banknifty.train_feature_finale already present
# ...

# %%
data_creation_obj.run_pipelines()
# Out:
# ****************************************************************************************************
# label_creator called with arguments {'freq': '1min', 'shift': -15, 'shift_column': 'close', 'generator_function_name': 'label_generator_4class_50points'}
# Column Status for label__minus_15_1min_close__label_generator_4class_50points is False
# Shape of OHLC dataframe is (1193346, 6)
# Shape of the dataframe before join (1193346, 2)
# Data type of label__minus_15_1min_close__label_generator_4class_50points : object
# Duckdb datatype of label__minus_15_1min_close__label_generator_4class_50points : VARCHAR
# alter sql is ALTER TABLE banknifty.train_feature_finale ADD COLUMN label__minus_15_1min_close__label_generator_4class_50points VARCHAR
# SQL to be run is UPDATE banknifty.train_feature_finale
#                     SET label__minus_15_1min_close__label_generator_4class_50points = data.label__minus_15_1min_close__label_generator_4class_50points
#                     FROM data
# ...

# %%
ignore_cols = ['PSARl_0.02_0.2_psar1','PSARs_0.02_0.2_psar1','PSARaf_0.02_0.2_psar1',
               'PSARr_0.02_0.2_psar1','PSARl_0.02_0.2_psar2',
               'PSARs_0.02_0.2_psar2','PSARaf_0.02_0.2_psar2','PSARr_0.02_0.2_psar2','PSARl_0.02_0.2_psar3'
               ,'PSARs_0.02_0.2_psar3','PSARaf_0.02_0.2_psar3','PSARr_0.02_0.2_psar3','PSARl_0.02_0.2_psar4',
               'PSARs_0.02_0.2_psar4','PSARaf_0.02_0.2_psar4','PSARr_0.02_0.2_psar4','PSARl_0.02_0.2_psar5',
0_supertrend_close20,SUPERTd_240_3.0_supertrend_close20,SUPERTl_240_3.0_supertrend_close20,SUPERTs_240_3.0_supertrend_close20,BBL_15_2.0_close,BBM_15_2.0_close,BBU_15_2.0_close,BBB_15_2.0_close,BBP_15_2.0_close,BBL_30_2.0_close,BBM_30_2.0_close,BBU_30_2.0_close,BBB_30_2.0_close,BBP_30_2.0_close,BBL_45_2.0_close,BBM_45_2.0_close,BBU_45_2.0_close,BBB_45_2.0_close,BBP_45_2.0_close,BBL_60_2.0_close,BBM_60_2.0_close,BBU_60_2.0_close,BBB_60_2.0_close,BBP_60_2.0_close,BBL_120_2.0_close,BBM_120_2.0_close,BBU_120_2.0_close,BBB_120_2.0_close,BBP_120_2.0_close,BBL_240_2.0_close,BBM_240_2.0_close,BBU_240_2.0_close,BBB_240_2.0_close,BBP_240_2.0_close,BBL_15_2.0_close10,BBM_15_2.0_close10,BBU_15_2.0_close10,BBB_15_2.0_close10,BBP_15_2.0_close10,BBL_30_2.0_close10,BBM_30_2.0_close10,BBU_30_2.0_close10,BBB_30_2.0_close10,BBP_30_2.0_close10,BBL_45_2.0_close10,BBM_45_2.0_close10,BBU_45_2.0_close10,BBB_45_2.0_close10,BBP_45_2.0_close10,BBL_60_2.0_close10,BBM_60_2.0_close10,BBU_60_2.0_close10,BBB_60_2.0_close10,BBP_60_2.0_close10,BBL_120_2.0_close10,BBM_120_2.0_close10,BBU_120_2.0_close10,BBB_120_2.0_close10,BBP_120_2.0_close10,BBL_240_2.0_close10,BBM_240_2.0_close10,BBU_240_2.0_close10,BBB_240_2.0_close10,BBP_240_2.0_close10,BBL_15_2.0_close20,BBM_15_2.0_close20,BBU_15_2.0_close20,BBB_15_2.0_close20,BBP_15_2.0_close20,BBL_30_2.0_close20,BBM_30_2.0_close20,BBU_30_2.0_close20,BBB_30_2.0_close20,BBP_30_2.0_close20,BBL_45_2.0_close20,BBM_45_2.0_close20,BBU_45_2.0_close20,BBB_45_2.0_close20,BBP_45_2.0_close20,BBL_60_2.0_close20,BBM_60_2.0_close20,BBU_60_2.0_close20,BBB_60_2.0_close20,BBP_60_2.0_close20,BBL_120_2.0_close20,BBM_120_2.0_close20,BBU_120_2.0_close20,BBB_120_2.0_close20,BBP_120_2.0_close20,BBL_240_2.0_close20,BBM_240_2.0_close20,BBU_240_2.0_close20,BBB_240_2.0_close20,BBP_240_2.0_close20"
t = t.split(",")
ignore_cols = ignore_cols+t
len(ignore_cols)
# Out:
# 187

# %%
feature_sel_obj = du.execute_feature_selection_pipeline(master_config_path=master_config_path, 
                                                        master_config_name=master_config_name, 
                                                        db_connection = None, 
                                                        database_path = database_path,
                                                        feature_selection_spec_name = feature_selection_spec, 
                                                        train_feature_table=train_feature_table,
                                                        train_feature_selection_table = train_feature_selection_table,
                                                        train_feature_info_table=train_feature_info_table,
                                                        filter_out_cols=filter_out_cols,
                                                        ignore_cols=ignore_cols,
                                                        verbose=True)
# Out:
# Feature selection spec file is data.feature_selection_specs.feature_wiz_spec
# ['+master=banknifty_master'] ../../config/
#  'SUPERT_30_3.0_supertrend_close',
#  'SUPERTd_30_3.0_supertrend_close',
#  'SUPERTl_30_3.0_supertrend_close',
#  'SUPERTs_30_3.0_supertrend_close',
#  'SUPERT_45_3.0_supertrend_close',
#  'SUPERTd_45_3.0_supertrend_close',
#  'SUPERTl_45_3.0_supertrend_close',
#  'SUPERTs_45_3.0_supertrend_close',
#  'SUPERT_60_3.0_supertrend_close',
#  'SUPERTd_60_3.0_supertrend_close',
#  'SUPERTl_60_3.0_supertrend_close',
#  'SUPERTs_60_3.0_supertrend_close',
#  'SUPERT_120_3.0_supertrend_close',
#  'SUPERTd_120_3.0_supertrend_close',
#  'SUPERTl_120_3.0_supertrend_close',
#  'SUPERTs_120_3.0_supertrend_close',
#  'SUPERT_240_3.0_supertrend_close',
#  'SUPERTd_240_3.0_supertrend_close',
#  'SUPERTl_240_3.0_supertrend_close',
#  'SUPERTs_240_3.0_supertrend_close',
#  'SUPERT_15_3.0_supertrend_close10',
#  'SUPERTd_15_3.0_supertrend_close10',
# ...

# %%
db_connection = duckdb.connect(database=database_path , read_only=False)

# %%
db_connection.close()

# %%
#ddu.drop_object(connection=con,object_type='table',object_name='banknifty.train_feature_final')

# %%
y = ddu.load_table_df(connection=db_connection,table_name='banknifty.train_feature_selection_improved_one')
#y = y.sort_values(by='timestamp')
y.head()
# Out:
#                                           label_name feature_selection_method  \
# 0  label__minus_15_1min_close__label_generator_4c...                  classic
# 1  label__minus_15_1min_close__label_generator_4c...                  classic
# 2  label__minus_15_1min_close__label_generator_4c...                  classic
# 3  label__minus_15_1min_close__label_generator_4c...                  classic
# 4  label__minus_15_1min_close__label_generator_4c...                  classic
#
#                          feature_name selection_flag  feature_importance  \
# 0        ROLLSTT_120_2_MEANDIFF_close              Y                 0.0
# 1         ROLLSTT_45_2_MAXMIN_close20              Y                 0.0
# 2    ROLLRNK_EMA_15_ema_close_15_None              Y                 0.0
# 3           ROLLDIFF_0_0_super_diff13              Y                 0.0
# 4  ROLLRNK_EMA_45_ema_close10_60_None              Y                 0.0
#
# ...

# %%
y
# Out:
#                                              label_name  \
# 0     label__minus_15_1min_close__label_generator_4c...
# 1     label__minus_15_1min_close__label_generator_4c...
# 2     label__minus_15_1min_close__label_generator_4c...
# 3     label__minus_15_1min_close__label_generator_4c...
# 4     label__minus_15_1min_close__label_generator_4c...
# ...                                                 ...
# 4817  label__minus_60_1min_close__label_generator_4c...
# 4818  label__minus_60_1min_close__label_generator_4c...
# 4819  label__minus_60_1min_close__label_generator_4c...
# 4820  label__minus_60_1min_close__label_generator_4c...
# 4821  label__minus_60_1min_close__label_generator_4c...
#
#      feature_selection_method  \
# 0                     classic
# 1                     classic
# 2                     classic
# 3                     classic
# 4                     classic
# ...                       ...
# 4817                  classic
# 4818                  classic
# ...

# %%
y[y['feature_name']=='ROLLDIFF_0_0_dc4_3']
# Out:
#                                              label_name  \
# 740   label__minus_30_1min_close__label_generator_4c...
# 2222  label__minus_30_1min_close__label_generator_4c...
# 3670  label__minus_30_1min_close__label_generator_4c...
# 4222  label__minus_45_1min_close__label_generator_4c...
#
#      feature_selection_method        feature_name selection_flag  \
# 740                   classic  ROLLDIFF_0_0_dc4_3              Y
# 2222                  classic  ROLLDIFF_0_0_dc4_3              Y
# 3670                  classic  ROLLDIFF_0_0_dc4_3              Y
# 4222                  classic  ROLLDIFF_0_0_dc4_3              Y
#
#       feature_importance                         label_mapper  \
# 740                  0.0  {'neutral': 0, 'put': 1, 'call': 2}
# 2222                 0.0  {'neutral': 0, 'call': 1, 'put': 2}
# 3670                 0.0  {'call': 0, 'put': 1, 'neutral': 2}
# 4222                 0.0  {'call': 0, 'put': 1, 'neutral': 2}
#
#               updated_timestamp
# ...

# %%
import pandas as pd
k = pd.DataFrame(y[['label_name','selection_flag']].value_counts()).reset_index()
k.columns = ['label_name','selection_flag','fetaure_count']
k
# Out:
#                                            label_name selection_flag  \
# 0   label__minus_60_1min_close__label_generator_4c...              Y
# 1   label__minus_15_1min_close__label_generator_4c...              Y
# 2   label__minus_45_1min_close__label_generator_4c...              Y
# 3   label__minus_60_1min_close__label_generator_4c...              Y
# 4   label__minus_15_1min_close__label_generator_4c...              Y
# 5   label__minus_60_1min_close__label_generator_4c...              Y
# 6   label__minus_30_1min_close__label_generator_4c...              Y
# 7   label__minus_30_1min_close__label_generator_4c...              Y
# 8   label__minus_45_1min_close__label_generator_4c...              Y
# 9   label__minus_45_1min_close__label_generator_4c...              Y
# 10  label__minus_15_1min_close__label_generator_4c...              Y
# 11  label__minus_30_1min_close__label_generator_4c...              Y
#
#     fetaure_count
# 0             452
# 1             442
# ...

# %%
k.loc[0]['label_name']
# Out:
# 'label__minus_45_1min_close__label_generator_4class'

# %%
y[y['label_name']=='label__minus_45_1min_close__label_generator_4class']['feature_name'].tolist()
# Out:
# ['TRUERANGE_120_hlc',
#  'ROLLRNK_EMA_60_ema_close_15_None',
#  'EMA_60_ema_close',
#  'BBB_15_20_close',
#  'ROLLSTT__45_2_MAXMIN_close',
#  'RVI_60_hl',
#  'ROLLSTT__240_2_MAXMIN_close20',
#  'ROLLPCM_BBM_240_20_close_60_None',
#  'RVI_120_hl',
#  'ROLLRNK_EMA_240_ema_close_15_None',
#  'ROLLPCM_SUPERTs_240_30_supertrend_close20_60_None',
#  'ROLLDIFF__0_0_super_diff13',
#  'ROLLPCM_SUPERTs_240_30_supertrend_close_60_None',
#  'ROLLPCM_SUPERTs_30_30_supertrend_close_60_None',
#  'RVI_240_hl',
#  'ROLLDIFF__0_0_super_diff2',
#  'ROLLLBC__120_0_2_0_MAXDIFF_close',
#  'ROLLSTT__120_2_MAXMIN_close',
#  'ROLLPCM_SUPERTs_45_30_supertrend_close20_60_None',
#  'ROLLDIFF__0_0_ema5',
#  'ROLLPCM_SUPERTl_45_30_supertrend_close_15_None',
#  'ROLLPCM_SUPERTl_15_30_supertrend_close10_60_None',
#  'ROLLSTT__240_2_MINDIFF_close',
#  'ROLLPCM_SUPERTl_30_30_supertrend_close20_30_None',
#  'ROLLPCM_SUPERTs_120_30_supertrend_close20_30_None',
#  'ROLLLBC__120_20_2_20_MAXDIFF_close20',
# ...
