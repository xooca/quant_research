# %%
import pandas as pd

# %%
import sys,os
project_path = "/content/drive/MyDrive/Work/quantitative_research/"
#database_path = "/content/drive/MyDrive/Work/trading_updated/database/development/develop"

sys.path.append(project_path)

import data.utils.duckdb_utils as ddu
import duckdb
import data.utils.data_utils as du
import modelling.training.trainer_v3 as tr

#from featurewiz import featurewiz
import random
import lightgbm as lgb
import numpy as np
import sklearn.metrics as mt

# %%
duckdb.__version__
# Out:
# '0.5.1'

# %%
url = 'https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files'
ext = '0.4.0-oneiric1_amd64.deb -qO'
# !wget $url/libta-lib0_$ext libta.deb
# !wget $url/ta-lib0-dev_$ext ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
# Out:
# Selecting previously unselected package libta-lib0.
# (Reading database ... 128276 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# Selecting previously unselected package ta-lib0-dev.
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.0/272.0 KB 7.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install duckdb==0.5.1
# !pip install hydra-core
# !pip install featurewiz
# !pip install xverse
# !pip install feature_engine
# !pip install shap-hypetune
# !pip install TA-Lib-binary
# !pip install -U git+https://github.com/twopirllc/pandas-ta
# !pip install ta
# !pip install mlxtend --upgrade --no-deps
# !pip install optuna

#!pip install lightgbm==3.3.2
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 56.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 KB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=8166ab2d6a0fc07ebf1ad3d231bd7ec23c94604c989ff996a641a142cc49a7ed
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built antlr4-python3-runtime
# ...

# %%
tuning_spec = "modelling.model_tuning_specs.catboost_tuning_v2"
tuning_spec = "modelling.model_tuning_specs.lightgbm_tuningv2"

database_path = "/content/drive/Othercomputers/My Mac/google_drive/database/production/banknifty_final1.duckdb"
db_connection = duckdb.connect(database=database_path , read_only=False)
data_suffix = 'improved_one'
train_feature_table = f'banknifty.train_feature_{data_suffix}'
train_feature_info_table = f'banknifty.train_feature_info_{data_suffix}'
train_feature_selection_table = f'banknifty.train_feature_selection_{data_suffix}'
train_training_info_table = f'banknifty.train_training_info_{data_suffix}'
train_tuning_info_table = f'banknifty.train_tuning_info_{data_suffix}'
ohlcraw_table = 'banknifty.ohlc_raw_data'

master_config_path = "../../config/"
master_config_name = 'banknifty_master'
filter_out_cols =["CMF_","RVGIs_","SSF_","STDEVALL","DPO_","ICS_","KAMA_","PDIST","RVGI_","PSAR","QS_","MCGD_10"]

ignore_column = ['ROLLDIFF_0_0_dc2_4',
 'ROLLDIFF_0_0_dc4_3',
 'ROLLDIFF_0_0_dc3_4',
 'ROLLDIFF_0_0_dc2_3',
 'ROLLDIFF_0_0_dc3_3',
 'ROLLDIFF_0_0_dc4_4']


pipeline_obj = tr.define_pipeline(specification_name=tuning_spec,
                                               master_config_path=master_config_path, 
                                               master_config_name=master_config_name, 
                                               db_connection = db_connection, 
                                               database_path = None,
                                               train_feature_table=train_feature_table,
                                               train_feature_selection_table = train_feature_selection_table,
                                               train_feature_info_table=train_feature_info_table,
                                               train_training_info_table=train_training_info_table,
                                               train_tuning_info_table=train_tuning_info_table,
                                               ignore_column = ignore_column,
                                               verbose=True)
# Out:
# Specification Name is file is modelling.model_tuning_specs.lightgbm_tuningv2
# ['+master=banknifty_master'] ../../config/
# ['+data=data', '+model=pycaret_v4', '+common=common'] ../../config/banknifty/
# Ignore columns are []
# Table name is banknifty.train_tuning_info_improved_one

# %%
#db_connection.close()

# %%
prob_theshold_list = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.81,0.82,0.83,0.84,0.85,0.86,0.87,0.89,0.9,0.91]
#model_fit_params={"early_stopping_rounds":300, "verbose":100, "eval_metric":'multi_logloss'}
model_fit_params={"early_stopping_rounds":100, "verbose":100}



#feature_selection_method='featurewiz'
feature_selection_method='classic'

# %%
forced_labels = ['label__minus_15_1min_close__label_generator_4class',
 'label__minus_30_1min_close__label_generator_4class',
 'label__minus_45_1min_close__label_generator_4class',
 'label__minus_60_1min_close__label_generator_4class']
forced_label_name = ['label__minus_15_1min_close__label_generator_4class']



pipeline_obj.run_tuning_pipelines(only_run_for_label = forced_labels,
                                    forced_labels = [],
                                    feature_selection_method=feature_selection_method,
                                    
                                    limit=3)
# Out:
#  ........ label__minus_60_1min_close__label_generator_4class_mod1 .........
# Number of features column before ignore col 404 for label label__minus_60_1min_close__label_generator_4class_mod1
# Number of features column after ignore col 404 for label label__minus_60_1min_close__label_generator_4class_mod1
# Number of features column are 404 for label label__minus_60_1min_close__label_generator_4class_mod1
#  ........ label__minus_60_1min_close__label_generator_4class_mod2 .........
# Number of features column before ignore col 404 for label label__minus_60_1min_close__label_generator_4class_mod2
# Number of features column after ignore col 404 for label label__minus_60_1min_close__label_generator_4class_mod2
# Number of features column are 404 for label label__minus_60_1min_close__label_generator_4class_mod2
#  ........ label__minus_45_1min_close__label_generator_4class .........
# ...

# %%
sql = f"select * from {train_feature_table} limit 10 "
z = ddu.load_table_df(db_connection,table_name=None,column_names=None,filter=None,load_sql=sql)
z.shape
# Out:
# (10, 1900)

# %%
#for col in z.columns.tolist():
#  print(col)

# %%
[c for c in z.columns.tolist() if 'Psar' in c]
# Out:
# []

# %%
sql = f'''
delete from banknifty.train_feature_selection_improved_one where feature_name in ('ROLLDIFF_0_0_dc2_4','ROLLDIFF_0_0_dc4_3','ROLLDIFF_0_0_dc3_4','ROLLDIFF_0_0_dc2_3','ROLLDIFF_0_0_dc3_3','ROLLDIFF_0_0_dc4_4')
'''
print(sql)
# Out:
# delete from banknifty.train_feature_selection_improved_one where feature_name in ('ROLLDIFF_0_0_dc2_4','ROLLDIFF_0_0_dc4_3','ROLLDIFF_0_0_dc3_4','ROLLDIFF_0_0_dc2_3','ROLLDIFF_0_0_dc3_3','ROLLDIFF_0_0_dc4_4')

# %%
ddu.execute_sql(db_connection,sql)

# %%
db_connection.close()

# %%
y = ddu.load_table_df(connection=db_connection,table_name='banknifty.train_feature_selection_improved_one')
#y = y.sort_values(by='timestamp')
y.head()
# Out:
#                                           label_name feature_selection_method  \
# 0  label__minus_15_1min_close__label_generator_4c...                  classic
# 1  label__minus_15_1min_close__label_generator_4c...                  classic
# 2  label__minus_15_1min_close__label_generator_4c...                  classic
# 3  label__minus_15_1min_close__label_generator_4c...                  classic
# 4  label__minus_15_1min_close__label_generator_4c...                  classic
#
#                          feature_name selection_flag  feature_importance  \
# 0        ROLLSTT_120_2_MEANDIFF_close              Y                 0.0
# 1         ROLLSTT_45_2_MAXMIN_close20              Y                 0.0
# 2    ROLLRNK_EMA_15_ema_close_15_None              Y                 0.0
# 3           ROLLDIFF_0_0_super_diff13              Y                 0.0
# 4  ROLLRNK_EMA_45_ema_close10_60_None              Y                 0.0
#
# ...

# %%
[c for c in list(set(y['feature_name'].tolist())) if 'PSAR' in c]
# Out:
# []

# %%
for col in list(set(y['feature_name'].tolist())) :
  print(col)
# Out:
# ROLLSTT_45_2_MINDIFF_close
# ROLLPCM_BBM_15_20_close20_15_None
# ROLLPCM_DCL_60_60_don8_60_None
# DIFFCOL_BBU_15_20_close10_close
# ROLLPCM_BBL_15_20_close_60_None
# ROLLPCM_SUPERT_240_30_supertrend_close20_15_None
# DIFFCOL_DCU_240_240_don5_close
# ROLLPCM_SUPERTs_120_30_supertrend_close_60_None
# DIFFCOL_BBL_120_20_close10_close
# ROLLPCM_BBU_120_20_close_30_None
# DMN_240_adx18
# DIFFCOL_SUPERT_45_30_supertrend_close20_close
# ROLLPCM_BBU_30_20_close20_15_None
# ROLLPCM_SUPERTs_15_30_supertrend_close10_30_None
# ROLLPCM_BBM_240_20_close_15_None
# ROLLDIFF_0_0_bb3
# ROLLSTT_15_2_MAXMIN_close
# DMP_15_adx1
# ROLLPCM_BBU_30_20_close20_30_None
# DMN_60_adx10
# AROONOSC_120_aroon9
# ROLLPCM_DCM_20_20_hl30_30_None
# ROLLRNK_DCM_30_30_don7_15_None
# AROOND_240_aroon15
# DIFFCOL_BBU_45_20_close20_close
# ROLLPCM_SUPERT_15_30_supertrend_close_15_None
# ROLLPCM_SUPERTs_120_30_supertrend_close20_60_None
# ROLLPCM_DCL_240_240_don10_30_None
# DIFFCOL_DCL_20_20_hl40_close
# ...

# %%
l = list(set(y['feature_name'].tolist()))
k = z.columns.tolist()

# %%
[c for c in l if c not in k]
# Out:
# ['ROLLDIFF_0_0_dc2_4',
#  'ROLLDIFF_0_0_dc4_3',
#  'ROLLDIFF_0_0_dc3_4',
#  'ROLLDIFF_0_0_dc2_3',
#  'ROLLDIFF_0_0_dc3_3',
#  'ROLLDIFF_0_0_dc4_4']

# %%
from modelling.model_tuning_specs import catboost_tuning as ct
ct.ProfitMetricAll()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-8435c69c9b00> in <module>
#       1 from modelling.model_tuning_specs import catboost_tuning as ct
# ----> 2 ct.ProfitMetricAll().name
#
# AttributeError: 'ProfitMetricAll' object has no attribute 'name'

# %%
a = ct.ProfitMetricMinority()
a.

# %%
str(ct.ProfitMetricMinority.mro()[0]).split('>')[0].split("'")[-2].split(".")[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-1e4db3219910> in <module>
# ----> 1 str(ct.ProfitMetricMinority().mro()[0]).split('>')[0].split("'")[-2].split(".")[-1]
#
# AttributeError: 'ProfitMetricMinority' object has no attribute 'mro'

# %%
sql = f"select * from banknifty.train_feature_selection_finale"
info = ddu.load_table_df(db_connection,table_name=None,column_names=None,filter=None,load_sql=sql)
#unstable_columns = info[info['column_type']=='unstable_column']['feature_name'].tolist()
#feature_columns = info[info['column_type']=='feature']['feature_name'].tolist()
info
# Out:
#                                              label_name  \
# 0     label__minus_15_1min_close__label_generator_4c...
# 1     label__minus_15_1min_close__label_generator_4c...
# 2     label__minus_15_1min_close__label_generator_4c...
# 3     label__minus_15_1min_close__label_generator_4c...
# 4     label__minus_15_1min_close__label_generator_4c...
# ...                                                 ...
# 3596  label__minus_60_1min_close__label_generator_3c...
# 3597  label__minus_60_1min_close__label_generator_3c...
# 3598  label__minus_60_1min_close__label_generator_3c...
# 3599  label__minus_60_1min_close__label_generator_3c...
# 3600  label__minus_60_1min_close__label_generator_3c...
#
#      feature_selection_method                                feature_name  \
# 0                     classic                                volatile_ATR
# 1                     classic                                     NATR_14
# ...

# %%
info['label_name'].value_counts()

# %%
a = ['time_split_validation_fold_11', 'time_split_validation_fold_7', 'time_split_validation_fold_4'] 
get_index = random.randrange(len(a))
get_index
# Out:
# 0

# %%
lst = ['a', 'a','a', 'a','b','c','b','b','b','b']
c =list(set(lst))

# %%
str1 = "','".join(c)
str1 = f"'{str1}'"
print(str1)
# Out:
# 'a','c','b'

# %%
combinations = [['a','b','c'],['a1','b1','c1'],['a2','b2','c2'],['a4','b4','c4'],['a412211','b432321','c4323231'],['a41','b41','c41'],['a114','b114','c114'],['a','b','c'],['a1','b1','c1'],['a444','b444','c444']]
import numpy as np
combinations_t = np.array(combinations)

# %%
combinations_t.shape
# Out:
# (10, 3)

# %%
combinations_t.shape[1]/stride
# Out:
# 1.5

# %%
combinations_t = np.array(combinations)
combinations_t = combinations_t.T
final = []
j = 0
stride = 4
chunks = 4
chunks = int(combinations_t.shape[1]/stride)
for i in range(chunks):
  final.append([list(combinations_t[i][j:j+stride]) for i in range(0,3)])
  j = j + stride
final
# Out:
# [[['a', 'a1', 'a2', 'a4'], ['b', 'b1', 'b2', 'b4'], ['c', 'c1', 'c2', 'c4']],
#  [['a412211', 'a41', 'a114', 'a'],
#   ['b432321', 'b41', 'b114', 'b'],
#   ['c4323231', 'c41', 'c114', 'c']]]

# %%
database_path = "/content/drive/MyDrive/Work/trading_updated/database/development/banknifty 2.duckdb"
db_connection = duckdb.connect(database=database_path , read_only=False)

#db_connection.close()

# %%
sql = f"select * from banknifty.train_feature_selection_finale"
info = ddu.load_table_df(db_connection,table_name=None,column_names=None,filter=None,load_sql=sql)
#unstable_columns = info[info['column_type']=='unstable_column']['feature_name'].tolist()
#feature_columns = info[info['column_type']=='feature']['feature_name'].tolist()
info
# Out:
#                                              label_name  \
# 0     label__minus_15_1min_close__label_generator_4c...
# 1     label__minus_15_1min_close__label_generator_4c...
# 2     label__minus_15_1min_close__label_generator_4c...
# 3     label__minus_15_1min_close__label_generator_4c...
# 4     label__minus_15_1min_close__label_generator_4c...
# ...                                                 ...
# 3596  label__minus_60_1min_close__label_generator_3c...
# 3597  label__minus_60_1min_close__label_generator_3c...
# 3598  label__minus_60_1min_close__label_generator_3c...
# 3599  label__minus_60_1min_close__label_generator_3c...
# 3600  label__minus_60_1min_close__label_generator_3c...
#
#      feature_selection_method                                feature_name  \
# 0                     classic                                volatile_ATR
# 1                     classic                                     NATR_14
# ...

# %%
sql = f"select * from banknifty.train_feature_info_finale"
info = ddu.load_table_df(db_connection,table_name=None,column_names=None,filter=None,load_sql=sql)
unstable_columns = info[info['column_type']=='unstable_column']['feature_name'].tolist()
feature_columns = info[info['column_type']=='feature']['feature_name'].tolist()

# %%
info['column_type'].value_counts()
# Out:
# feature            1466
# unstable_column     119
# null_reject         106
# label                28
# ohlc_column           7
# splittercolumn        1
# Name: column_type, dtype: int64

# %%
unstable_columns = info[info['column_type']=='unstable_column']['feature_name'].tolist()
feature_columns = info[info['column_type']=='feature']['feature_name'].tolist()
# Out:
#       function_name                                       feature_name  \
# 0     label_creator  label__minus_15_1min_close__label_generator_4c...
# 1     label_creator  label__minus_30_1min_close__label_generator_4c...
# 2     label_creator  label__minus_45_1min_close__label_generator_4c...
# 3     label_creator  label__minus_60_1min_close__label_generator_4c...
# 4     label_creator  label__minus_15_1min_close__label_generator_4c...
# ...             ...                                                ...
# 1722  label_creator  label__minus_60_1min_close__label_generator_3c...
# 1723  label_creator  label__minus_15_1min_close__label_generator_3c...
# 1724  label_creator  label__minus_30_1min_close__label_generator_3c...
# 1725  label_creator  label__minus_45_1min_close__label_generator_3c...
# 1726  label_creator  label__minus_60_1min_close__label_generator_3c...
#
#                 max_date            min_date status column_type  \
# ...

# %%
dict(info)
# Out:
# {'label_name': Series([], Name: label_name, dtype: object),
#  'feature_selection_method': Series([], Name: feature_selection_method, dtype: object),
#  'feature_name': Series([], Name: feature_name, dtype: object),
#  'selection_flag': Series([], Name: selection_flag, dtype: object),
#  'feature_importance': Series([], Name: feature_importance, dtype: float64),
#  'label_mapper': Series([], Name: label_mapper, dtype: object),
#  'updated_timestamp': Series([], Name: updated_timestamp, dtype: datetime64[ns])}

# %%
ddu.drop_object(connection=db_connection,object_type='table',object_name='banknifty.train_feature_info')
# Out:
# DROP sql is DROP table IF EXISTS banknifty.train_feature_info

# %%
db_connection.close()

# %%
#a = info['train_partition'].tolist()
#b = info['test_partition'].tolist()
#c = info['validation_partition'].tolist()
sql = f"select * from banknifty.train_feature_info"
info = ddu.load_table_df(db_connection,table_name=None,column_names=None,filter=None,load_sql=sql)
col_list = info['label_name'].unique()
all_dict = {}
for col in col_list:
  info_tmp = info[info['label_name']==col]
  a = info_tmp['train_partition'].tolist()
  b = info_tmp['test_partition'].tolist()
  c = info_tmp['validation_partition'].tolist()
  #for i,j,k in zip(a,b,c):
  all_dict.update({col:{'train':a,'test':b,'validation':c}})

# %%
already_trained = ['a','b','c']
force_train = ['a','b']
[col for col in already_trained if col not in force_train]
# Out:
# ['c']

# %%
info['train_partition'].tolist()
# Out:
# ['time_split_train_fold_6',
#  'time_split_train_fold_1',
#  'time_split_train_fold_7',
#  'time_split_train_fold_12',
#  'time_split_train_fold_12',
#  'time_split_train_fold_10',
#  'time_split_train_fold_2',
#  'time_split_train_fold_6',
#  'time_split_train_fold_5',
#  'time_split_train_fold_11',
#  'time_split_train_fold_1',
#  'time_split_train_fold_7',
#  'time_split_train_fold_5',
#  'time_split_train_fold_1',
#  'time_split_train_fold_12',
#  'time_split_train_fold_2',
#  'time_split_train_fold_11',
#  'time_split_train_fold_2',
#  'time_split_train_fold_12',
#  'time_split_train_fold_3']

# %%
info['test_partition'].tolist()
# Out:
# ['time_split_test_fold_11',
#  'time_split_test_fold_9',
#  'time_split_test_fold_2',
#  'time_split_test_fold_1',
#  'time_split_test_fold_8',
#  'time_split_test_fold_6',
#  'time_split_test_fold_11',
#  'time_split_test_fold_2',
#  'time_split_test_fold_1',
#  'time_split_test_fold_7',
#  'time_split_test_fold_5',
#  'time_split_test_fold_11',
#  'time_split_test_fold_1',
#  'time_split_test_fold_6',
#  'time_split_test_fold_7',
#  'time_split_test_fold_6',
#  'time_split_test_fold_7',
#  'time_split_test_fold_6',
#  'time_split_test_fold_2',
#  'time_split_test_fold_7']

# %%
info['validation_partition'].tolist()
# Out:
# ['time_split_validation_fold_2',
#  'time_split_validation_fold_5',
#  'time_split_validation_fold_11',
#  'time_split_validation_fold_7',
#  'time_split_validation_fold_4',
#  'time_split_validation_fold_1',
#  'time_split_validation_fold_6',
#  'time_split_validation_fold_11',
#  'time_split_validation_fold_10',
#  'time_split_validation_fold_2',
#  'time_split_validation_fold_11',
#  'time_split_validation_fold_2',
#  'time_split_validation_fold_9',
#  'time_split_validation_fold_10',
#  'time_split_validation_fold_3',
#  'time_split_validation_fold_11',
#  'time_split_validation_fold_3',
#  'time_split_validation_fold_10',
#  'time_split_validation_fold_6',
#  'time_split_validation_fold_11']

# %%
info
# Out:
#                                            label_name training_algo  \
# 0   label__minus_15_1min_close__label_generator_9c...      lightgbm
# 1   label__minus_30_1min_close__label_generator_14...      lightgbm
# 2   label__minus_30_1min_close__label_generator_14...      lightgbm
# 3   label__minus_30_1min_close__label_generator_14...      lightgbm
# 4   label__minus_30_1min_close__label_generator_14...      lightgbm
# 5   label__minus_30_1min_close__label_generator_14...      lightgbm
# 6   label__minus_30_1min_close__label_generator_14...      lightgbm
# 7   label__minus_30_1min_close__label_generator_14...      lightgbm
# 8   label__minus_30_1min_close__label_generator_14...      lightgbm
# 9   label__minus_30_1min_close__label_generator_14...      lightgbm
# 10  label__minus_30_1min_close__label_generator_14...      lightgbm
# 11  label__minus_30_1min_close__label_generator_14...      lightgbm
# 12  label__minus_30_1min_close__label_generator_14...      lightgbm
# ...
