# %%
import sys,os

ENV = 'colab'
if ENV == 'colab':
    base_path = "/content/drive/Othercomputers/My Mac/"
    project_path = "/content/drive/Othercomputers/My Mac/Documents/trading"
else:
    base_path = "/Volumes/Seagate/"
    project_path = "/Users/prabhatkumar/Documents/trading/"
sys.path.append(project_path)    
import qml.data.utils.duckdb_utils as ddu
import duckdb
import qml.data.utils.data_utils as du

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
duckdb.__version__
# Out:
# '0.5.1'

# %%
url = 'https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files'
ext = '0.4.0-oneiric1_amd64.deb -qO'
# !wget $url/libta-lib0_$ext libta.deb
# !wget $url/ta-lib0-dev_$ext ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
# Out:
# Selecting previously unselected package libta-lib0.
# (Reading database ... 128288 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# Selecting previously unselected package ta-lib0-dev.
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta-lib
#   Downloading TA-Lib-0.4.25.tar.gz (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.0/272.0 KB 13.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from ta-lib) (1.22.4)
# Building wheels for collected packages: ta-lib
#   Building wheel for ta-lib (pyproject.toml) ... done
#   Created wheel for ta-lib: filename=TA_Lib-0.4.25-cp39-cp39-linux_x86_64.whl size=2261305 sha256=e0dff66234170ee8ebe25139e73149f36f4644db6734f7d10f4c214370f6b638
#   Stored in directory: /root/.cache/pip/wheels/a4/1e/ce/8f22bc445ab10758bc4e6babe45f688e199d3a1c6e7d28d32e
# Successfully built ta-lib
# Installing collected packages: ta-lib
# Successfully installed ta-lib-0.4.25

# %%
# !pip install duckdb==0.5.1
# !pip install hydra-core
# !pip install TA-Lib-binary
# !pip install -U git+https://github.com/twopirllc/pandas-ta
# !pip install feature_engine
# !pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting duckdb==0.5.1
#   Downloading duckdb-0.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.9/dist-packages (from duckdb==0.5.1) (1.22.4)
# Installing collected packages: duckdb
# Successfully installed duckdb-0.5.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hydra-core
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 KB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from hydra-core) (23.0)
# Collecting omegaconf<2.4,>=2.2
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 12.4 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 13.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.9/dist-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=30c5ab633a056d775b696b66acdc2944d42728d85085a76af2bc0d2a1633e33a
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf, hydra-core
# Successfully installed antlr4-python3-runtime-4.9.3 hydra-core-1.3.2 omegaconf-2.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement TA-Lib-binary (from versions: none)
# ERROR: No matching distribution found for TA-Lib-binary
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/twopirllc/pandas-ta
#   Cloning https://github.com/twopirllc/pandas-ta to /tmp/pip-req-build-6gpon70r
#   Running command git clone --filter=blob:none --quiet https://github.com/twopirllc/pandas-ta /tmp/pip-req-build-6gpon70r
#   Resolved https://github.com/twopirllc/pandas-ta to commit 084dbe1c4b76082f383fa3029270ea9ac35e4dc7
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pandas-ta==0.3.14b0) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandas-ta==0.3.14b0) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->pandas-ta==0.3.14b0) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandas-ta==0.3.14b0) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->pandas-ta==0.3.14b0) (1.16.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=219769 sha256=1ee6a97e6e17840c415ffcc53a207e5ed1aa977404dc78090e4c54dfa0113a9d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1kil9v74/wheels/20/45/7a/52ed064b376efce7aac331bdf6a48e0bb6a22f91ce864810d6
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feature_engine
#   Downloading feature_engine-1.6.0-py2.py3-none-any.whl (319 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.4/319.4 KB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (0.13.5)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.4.4)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.22.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.2.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature_engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature_engine) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature_engine) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature_engine) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature_engine) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature_engine) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature_engine) (1.16.0)
# Installing collected packages: feature_engine
# Successfully installed feature_engine-1.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from ta) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ta) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ta) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29103 sha256=3f44a4ad90c3d1d9f7e989c3afc68825f6f6aa8163a9b7d66253ef07a97d2428
#   Stored in directory: /root/.cache/pip/wheels/6a/76/03/7f785aaa50b9c6ec7e3fd105a62c1b2c45a034512d51e024a9
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %% [markdown]
# ## Define pipeline parameters

# %%
master_config_path = "../../../nifty/config/"
master_config_name = 'master_v1'
data_suffix = 'v1'
schema = 'nifty'

database_path = f"{base_path}google_drive/database/nifty.duckdb"
#db_connection = duckdb.connect(database=database_path , read_only=False)


feature_selection_spec = "qml.data.feature_selection_specs.feature_wiz_spec"
feature_spec_name = 'qml.data.feature_specs.feature_spec_final_v2'

train_feature_table = f'{schema}.train_feature_{data_suffix}'
train_feature_info_table = f'{schema}.train_feature_info_{data_suffix}'
train_feature_selection_table = f'{schema}.train_feature_selection_{data_suffix}'
train_training_info_table = f'{schema}.train_training_info_{data_suffix}'
train_tuning_info_table = f'{schema}.train_tuning_info_{data_suffix}'
ohlcraw_table = f'{schema}.ohlc_raw_data'

label_creation=False
techindicator1=False
techindicator2=True
techindicator3=False
time_splitter = True
column_unstable = True
update_unstable = True
load_tmp = False

#con = duckdb.connect(database=database_path , read_only=False)
filter_out_cols =["CMF_","RVGIs_","SSF_","STDEVALL","DPO_","ICS_","KAMA_","PDIST","RVGI_","PSAR","QS_"]

# %% [markdown]
# ## Create Data creation pipeline

# %%
obj = du.execute_data_pipeline(master_config_path, 
                               master_config_name, 
                               db_conection=None, 
                               database_path=database_path,
                               feature_spec_name=feature_spec_name,
                               train_feature_table=train_feature_table,
                               train_feature_info_table=train_feature_info_table,
                               techindicator1=techindicator1,
                               techindicator2=techindicator2,
                               techindicator3=techindicator3,
                               time_splitter = time_splitter,
                               column_unstable = column_unstable,
                               label_creation=label_creation,
                               update_unstable=update_unstable,
                               load_tmp = load_tmp)
# Out:
# Feature spec file is qml.data.feature_specs.feature_spec_final_v2
# ['+master=master_v1'] ../../../nifty/config/
# {'master': {'model': {'overrides': ['+data=data', '+common=common'], 'version_base': 'None', 'config_path': '../../../nifty/config/'}}}
# ['+data=data', '+common=common'] ../../../nifty/config/
# Shape of OHLC dataframe is (1380517, 6)
#             timestamp ticker   open   high    low  close
# 0 2017-11-28 09:08:00  NIFTY  10388  10388  10388  10388
# 1 2017-11-28 09:16:00  NIFTY  10391  10391  10372  10375
# 2 2017-11-28 09:17:00  NIFTY  10374  10383  10374  10382
# 3 2017-11-28 09:18:00  NIFTY  10384  10387  10381  10386
# 4 2017-11-28 09:19:00  NIFTY  10386  10390  10386  10388
# feature table is nifty.train_feature_v1
# feature info table is nifty.train_feature_info_v1
# Value of self.max_date_raw_table in nifty.ohlc_raw_data is 2023-02-21 15:32:00
# Value of self.max_date_feature_table is 2023-02-21 15:32:00
# Value of self.min_date_feature_table is 2008-01-01 09:55:00
# Table nifty.train_feature_v1 already present
# Table nifty.train_feature_info_v1 already created
# Number of already loaded features are 505

# %%
obj.feature_pipeline.feature_mart.ticker_name
# Out:
# 'nifty'

# %%
obj.run_pipelines()
# Out:
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/momentum/previousday_range.py' into category 'momentum'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/overlap/pricerange_hour.py' into category 'overlap'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/performance/rollvals.py' into category 'performance'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/performance/rollpercent_change.py' into category 'performance'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/performance/price_breach.py' into category 'performance'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/statistics/label_creator.py' into category 'statistics'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/statistics/diff_cols.py' into category 'statistics'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/trend/ni.py' into category 'trend'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/trend/rolltrends.py' into category 'trend'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/trend/rollrank.py' into category 'trend'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/volatility/rolllb.py' into category 'volatility'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/volatility/rolllbc_offset.py' into category 'volatility'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/volatility/rollbin.py' into category 'volatility'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/volatility/rollstat.py' into category 'volatility'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/volatility/rollgapopen.py' into category 'volatility'.
# [i] Successfully imported the custom indicator '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals/volatility/rolllbc.py' into category 'volatility'.
# ****************************************************************************************************
# create_technical_indicator_using_pandasta_list_one called with arguments {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals'}
# Running technical indicator pipeline pipe8
# Pipeline found {'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': 'None', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe8_1', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': None, 'suffix': 'close'}]}
# TA Definition is [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': None, 'suffix': 'close'}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe8_1', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': None, 'suffix': 'close'}]}
# [+] Strategy: pipe_desc_pipe8_1
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 5
# [i] Last Run: Sunday April 2, 2023, NYSE: 3:58:37, Local: 7:58:37 UTC, Day 92/365 (25.00%)
# [i] Runtime: 289420.5573 ms (289.4206 s)
# Shape of the dataframe before join (1380517, 6)
# Data type of ROLLSTT_15_2_DIFF_close : float64
# Duckdb datatype of ROLLSTT_15_2_DIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_15_2_DIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_15_2_DIFF_close = data.ROLLSTT_15_2_DIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_15_2_2_MAXDIFF_close : float64
# Duckdb datatype of ROLLSTT_15_2_2_MAXDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_15_2_2_MAXDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_15_2_2_MAXDIFF_close = data.ROLLSTT_15_2_2_MAXDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_15_2_MINDIFF_close : float64
# Duckdb datatype of ROLLSTT_15_2_MINDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_15_2_MINDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_15_2_MINDIFF_close = data.ROLLSTT_15_2_MINDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_15_2_MEANDIFF_close : float64
# Duckdb datatype of ROLLSTT_15_2_MEANDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_15_2_MEANDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_15_2_MEANDIFF_close = data.ROLLSTT_15_2_MEANDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_15_2_MAXMIN_close : float64
# Duckdb datatype of ROLLSTT_15_2_MAXMIN_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_15_2_MAXMIN_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_15_2_MAXMIN_close = data.ROLLSTT_15_2_MAXMIN_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_15_2_DIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_1', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 07:59:50.833033'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_15_2_2_MAXDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_1', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 07:59:50.838798'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_15_2_MINDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_1', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 07:59:50.841101'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_15_2_MEANDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_1', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 07:59:50.843016'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_15_2_MAXMIN_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_1', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 15, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 07:59:50.846271'} as tab)
#
# Pipeline found {'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': 'None', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe8_2', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': None, 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': None, 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe8_2', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': None, 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe8_2
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 5
# [i] Last Run: Sunday April 2, 2023, NYSE: 4:04:43, Local: 8:04:43 UTC, Day 92/365 (25.00%)
# [i] Runtime: 292044.3378 ms (292.0443 s)
# Shape of the dataframe before join (1380517, 6)
# Data type of ROLLSTT_30_2_DIFF_close : float64
# Duckdb datatype of ROLLSTT_30_2_DIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_30_2_DIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_30_2_DIFF_close = data.ROLLSTT_30_2_DIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_30_2_2_MAXDIFF_close : float64
# Duckdb datatype of ROLLSTT_30_2_2_MAXDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_30_2_2_MAXDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_30_2_2_MAXDIFF_close = data.ROLLSTT_30_2_2_MAXDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_30_2_MINDIFF_close : float64
# Duckdb datatype of ROLLSTT_30_2_MINDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_30_2_MINDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_30_2_MINDIFF_close = data.ROLLSTT_30_2_MINDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_30_2_MEANDIFF_close : float64
# Duckdb datatype of ROLLSTT_30_2_MEANDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_30_2_MEANDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_30_2_MEANDIFF_close = data.ROLLSTT_30_2_MEANDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_30_2_MAXMIN_close : float64
# Duckdb datatype of ROLLSTT_30_2_MAXMIN_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_30_2_MAXMIN_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_30_2_MAXMIN_close = data.ROLLSTT_30_2_MAXMIN_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_30_2_DIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_2', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:04:54.869908'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_30_2_2_MAXDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_2', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:04:54.874931'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_30_2_MINDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_2', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:04:54.877797'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_30_2_MEANDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_2', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:04:54.880640'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_30_2_MAXMIN_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_2', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 30, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:04:54.883143'} as tab)
#
# Pipeline found {'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': 'None', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe8_3', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': None, 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': None, 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe8_3', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': None, 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe8_3
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 5
# [i] Last Run: Sunday April 2, 2023, NYSE: 4:10:19, Local: 8:10:19 UTC, Day 92/365 (25.00%)
# [i] Runtime: 324465.5289 ms (324.4655 s)
# Shape of the dataframe before join (1380517, 6)
# Data type of ROLLSTT_45_2_DIFF_close : float64
# Duckdb datatype of ROLLSTT_45_2_DIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_45_2_DIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_45_2_DIFF_close = data.ROLLSTT_45_2_DIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_45_2_2_MAXDIFF_close : float64
# Duckdb datatype of ROLLSTT_45_2_2_MAXDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_45_2_2_MAXDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_45_2_2_MAXDIFF_close = data.ROLLSTT_45_2_2_MAXDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_45_2_MINDIFF_close : float64
# Duckdb datatype of ROLLSTT_45_2_MINDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_45_2_MINDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_45_2_MINDIFF_close = data.ROLLSTT_45_2_MINDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_45_2_MEANDIFF_close : float64
# Duckdb datatype of ROLLSTT_45_2_MEANDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_45_2_MEANDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_45_2_MEANDIFF_close = data.ROLLSTT_45_2_MEANDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_45_2_MAXMIN_close : float64
# Duckdb datatype of ROLLSTT_45_2_MAXMIN_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_45_2_MAXMIN_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_45_2_MAXMIN_close = data.ROLLSTT_45_2_MAXMIN_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_45_2_DIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_3', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:10:35.949285'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_45_2_2_MAXDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_3', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:10:35.954856'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_45_2_MINDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_3', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:10:35.959983'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_45_2_MEANDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_3', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:10:35.965609'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_45_2_MAXMIN_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_3', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 45, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:10:35.971037'} as tab)
#
# Pipeline found {'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': 'None', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe8_4', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': None, 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': None, 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe8_4', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': None, 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe8_4
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 5
# [i] Last Run: Sunday April 2, 2023, NYSE: 4:15:59, Local: 8:15:59 UTC, Day 92/365 (25.00%)
# [i] Runtime: 323521.1746 ms (323.5212 s)
# Shape of the dataframe before join (1380517, 6)
# Data type of ROLLSTT_60_2_DIFF_close : float64
# Duckdb datatype of ROLLSTT_60_2_DIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_60_2_DIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_60_2_DIFF_close = data.ROLLSTT_60_2_DIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_60_2_2_MAXDIFF_close : float64
# Duckdb datatype of ROLLSTT_60_2_2_MAXDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_60_2_2_MAXDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_60_2_2_MAXDIFF_close = data.ROLLSTT_60_2_2_MAXDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_60_2_MINDIFF_close : float64
# Duckdb datatype of ROLLSTT_60_2_MINDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_60_2_MINDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_60_2_MINDIFF_close = data.ROLLSTT_60_2_MINDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_60_2_MEANDIFF_close : float64
# Duckdb datatype of ROLLSTT_60_2_MEANDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_60_2_MEANDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_60_2_MEANDIFF_close = data.ROLLSTT_60_2_MEANDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_60_2_MAXMIN_close : float64
# Duckdb datatype of ROLLSTT_60_2_MAXMIN_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_60_2_MAXMIN_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_60_2_MAXMIN_close = data.ROLLSTT_60_2_MAXMIN_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_60_2_DIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_4', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:16:18.894434'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_60_2_2_MAXDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_4', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:16:18.899468'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_60_2_MINDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_4', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:16:18.904243'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_60_2_MEANDIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_4', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:16:18.907641'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_60_2_MAXMIN_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_4', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 60, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:16:18.910653'} as tab)
#
# Pipeline found {'kind': 'rollstat', 'close': 'close', 'length': 120, 'offset': 'None', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe8_5', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 120, 'offset': None, 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'rollstat', 'close': 'close', 'length': 120, 'offset': None, 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe8_5', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 120, 'offset': None, 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe8_5
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 5
# [i] Last Run: Sunday April 2, 2023, NYSE: 4:21:51, Local: 8:21:51 UTC, Day 92/365 (25.00%)
# [i] Runtime: 332593.9648 ms (332.5940 s)
# Shape of the dataframe before join (1380517, 6)
# Data type of ROLLSTT_120_2_DIFF_close : float64
# Duckdb datatype of ROLLSTT_120_2_DIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_120_2_DIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_120_2_DIFF_close = data.ROLLSTT_120_2_DIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_120_2_2_MAXDIFF_close : float64
# Duckdb datatype of ROLLSTT_120_2_2_MAXDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_120_2_2_MAXDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_120_2_2_MAXDIFF_close = data.ROLLSTT_120_2_2_MAXDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_120_2_MINDIFF_close : float64
# Duckdb datatype of ROLLSTT_120_2_MINDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_120_2_MINDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_120_2_MINDIFF_close = data.ROLLSTT_120_2_MINDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_120_2_MEANDIFF_close : float64
# Duckdb datatype of ROLLSTT_120_2_MEANDIFF_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_120_2_MEANDIFF_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_120_2_MEANDIFF_close = data.ROLLSTT_120_2_MEANDIFF_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# Data type of ROLLSTT_120_2_MAXMIN_close : float64
# Duckdb datatype of ROLLSTT_120_2_MAXMIN_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLSTT_120_2_MAXMIN_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLSTT_120_2_MAXMIN_close = data.ROLLSTT_120_2_MAXMIN_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLSTT_120_2_DIFF_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe8'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe8_5', 'ta': [{'kind': 'rollstat', 'close': 'close', 'length': 120, 'offset': 'None', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 08:22:10.367912'} as tab)
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
# ...
#
# Pipeline found {'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe16_2', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe16_2', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe16_2
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 1
# [i] Last Run: Sunday April 2, 2023, NYSE: 7:31:05, Local: 11:31:05 UTC, Day 92/365 (25.00%)
# [i] Runtime: 382972.4182 ms (382.9724 s)
# Shape of the dataframe before join (1380517, 2)
# Data type of ROLLBRC_30_0_close : int64
# Duckdb datatype of ROLLBRC_30_0_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLBRC_30_0_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLBRC_30_0_close = data.ROLLBRC_30_0_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLBRC_30_0_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe16'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe16_2', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 11:31:12.674154'} as tab)
#
# Pipeline found {'kind': 'price_breach', 'close': 'close', 'length': 45, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe16_3', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 45, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'price_breach', 'close': 'close', 'length': 45, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe16_3', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 45, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe16_3
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 1
# [i] Last Run: Sunday April 2, 2023, NYSE: 7:36:56, Local: 11:36:56 UTC, Day 92/365 (25.00%)
# [i] Runtime: 343696.9843 ms (343.6970 s)
# Shape of the dataframe before join (1380517, 2)
# Data type of ROLLBRC_45_0_close : int64
# Duckdb datatype of ROLLBRC_45_0_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLBRC_45_0_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLBRC_45_0_close = data.ROLLBRC_45_0_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLBRC_45_0_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe16'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe16_3', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 45, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 11:37:03.573231'} as tab)
#
# Pipeline found {'kind': 'price_breach', 'close': 'close', 'length': 60, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe16_4', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 60, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'price_breach', 'close': 'close', 'length': 60, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe16_4', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 60, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe16_4
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 1
# [i] Last Run: Sunday April 2, 2023, NYSE: 7:42:55, Local: 11:42:55 UTC, Day 92/365 (25.00%)
# [i] Runtime: 351665.7237 ms (351.6657 s)
# Shape of the dataframe before join (1380517, 2)
# Data type of ROLLBRC_60_0_close : int64
# Duckdb datatype of ROLLBRC_60_0_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLBRC_60_0_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLBRC_60_0_close = data.ROLLBRC_60_0_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLBRC_60_0_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe16'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe16_4', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 60, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 11:43:02.761199'} as tab)
#
# Pipeline found {'kind': 'price_breach', 'close': 'close', 'length': 120, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}
# PIPE CONFIG {'name': 'pipe_desc_pipe16_5', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 120, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# TA Definition is [{'kind': 'price_breach', 'close': 'close', 'length': 120, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe16_5', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 120, 'offset': None, 'breach_type': 'mean', 'suffix': 'close', 'append': True}]}
# [+] Strategy: pipe_desc_pipe16_5
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 1
# [i] Last Run: Sunday April 2, 2023, NYSE: 7:48:59, Local: 11:48:59 UTC, Day 92/365 (25.00%)
# [i] Runtime: 356598.1058 ms (356.5981 s)
# Shape of the dataframe before join (1380517, 2)
# Data type of ROLLBRC_120_0_close : int64
# Duckdb datatype of ROLLBRC_120_0_close : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLBRC_120_0_close DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLBRC_120_0_close = data.ROLLBRC_120_0_close
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLBRC_120_0_close', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe16'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe16_5', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 120, 'offset': 'None', 'breach_type': 'mean', 'suffix': 'close'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 11:49:06.829840'} as tab)
#
# Pipeline found {'kind': 'price_breach', 'close': 'close', 'length': 15, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20'}
# PIPE CONFIG {'name': 'pipe_desc_pipe16_6', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 15, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20', 'append': True}]}
# TA Definition is [{'kind': 'price_breach', 'close': 'close', 'length': 15, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe16_6', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 15, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20', 'append': True}]}
# [+] Strategy: pipe_desc_pipe16_6
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.
# [i] Total indicators: 1
# [i] Columns added: 1
# [i] Last Run: Sunday April 2, 2023, NYSE: 7:55:03, Local: 11:55:03 UTC, Day 92/365 (25.00%)
# [i] Runtime: 356769.4332 ms (356.7694 s)
# Shape of the dataframe before join (1380517, 2)
# Data type of ROLLBRC_15_20_close20 : float64
# Duckdb datatype of ROLLBRC_15_20_close20 : DOUBLE
# alter sql is ALTER TABLE nifty.train_feature_v1 ADD COLUMN ROLLBRC_15_20_close20 DOUBLE
# SQL to be run is UPDATE nifty.train_feature_v1
#                     SET ROLLBRC_15_20_close20 = data.ROLLBRC_15_20_close20
#                     FROM data
#                     WHERE nifty.train_feature_v1.timestamp = data.timestamp
#
# SQL to be run is
#             insert into nifty.train_feature_info_v1
#             select
#             tab.function_name,
#             tab.feature_name,
#             tab.max_date,
#             tab.min_date,
#             tab.status,
#             tab.column_type,
#             tab.feature_args,
#             tab.updated_timestamp from
#             (select {'function_name': 'create_technical_indicator_using_pandasta_list_one', 'feature_name': 'ROLLBRC_15_20_close20', 'max_date': '2023-02-21 15:32:00', 'min_date': '2008-01-01 09:55:00', 'status': 'saved', 'column_type': 'feature', 'feature_args': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'technical_indicator_pipeline': ['pipe16'], 'custom_signal_path': '/content/drive/MyDrive/Work/quantitative_research/data/custom_signals', 'pipe_config': {'name': 'pipe_desc_pipe16_6', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 15, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20'}]}, 'strategy_config': {'exclude': ['jma', 'pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt'], 'verbose': True, 'timed': True, 'lookahead': False}}, 'updated_timestamp': '2023-04-02 11:55:11.616892'} as tab)
#
# Pipeline found {'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20'}
# PIPE CONFIG {'name': 'pipe_desc_pipe16_7', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20', 'append': True}]}
# TA Definition is [{'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20', 'append': True}]
# TEMP COLS ['timestamp', 'close']
# Shape of OHLC dataframe is (1380517, 6)
# Shape of tempdf is (1380517, 6)
# Pipeline configuration is {'name': 'pipe_desc_pipe16_7', 'ta': [{'kind': 'price_breach', 'close': 'close', 'length': 30, 'offset': 20, 'breach_type': 'mean', 'suffix': 'close20', 'append': True}]}
# [+] Strategy: pipe_desc_pipe16_7
# [i] Indicator arguments: {'timed': True, 'lookahead': False, 'append': True}
# [i] Multiprocessing 1 indicators with 3 chunks and 4/4 cpus.

# %%
'''
db_connection = duckdb.connect(database=database_path , read_only=False)

ddu.drop_object(connection=db_connection,object_type='table',object_name=train_feature_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_feature_info_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_feature_selection_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_training_info_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_tuning_info_table)
db_connection.close()
'''
# Out:
# DROP sql is DROP table IF EXISTS banknifty.train_feature_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_feature_info_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_feature_selection_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_training_info_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_tuning_info_improved_one

# %%
db_connection = duckdb.connect(database=database_path , read_only=False)

# %%
y = ddu.load_table_df(connection=db_connection,table_name=train_feature_info_table)
#y = y.sort_values(by='timestamp')
y.head()
# Out:
#    function_name                                       feature_name  \
# 0  label_creator  label__minus_15_1min_close__label_generator_4c...
# 1  label_creator  label__minus_30_1min_close__label_generator_4c...
# 2  label_creator  label__minus_45_1min_close__label_generator_4c...
# 3  label_creator  label__minus_60_1min_close__label_generator_4c...
# 4  label_creator  label__minus_15_1min_close__label_generator_4c...
#
#              max_date            min_date status column_type  \
# 0 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 1 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 2 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 3 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 4 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
#
#                                         feature_args  \
# 0  {'freq': 1min, 'shift': -15, 'shift_column': c...
# 1  {'freq': 1min, 'shift': -30, 'shift_column': c...
# 2  {'freq': 1min, 'shift': -45, 'shift_column': c...
# 3  {'freq': 1min, 'shift': -60, 'shift_column': c...
# 4  {'freq': 1min, 'shift': -15, 'shift_column': c...
#
#            updated_timestamp
# 0 2023-03-19 11:28:51.064746
# 1 2023-03-19 11:28:57.786420
# 2 2023-03-19 11:29:04.771801
# 3 2023-03-19 11:29:11.719954
# 4 2023-03-19 11:29:18.623249

# %%
y['column_type'].value_counts()
# Out:
# feature            1645
# unstable_column     292
# null_reject         166
# label                16
# ohlc_column           4
# splittercolumn        1
# Name: column_type, dtype: int64

# %%
con.close()
