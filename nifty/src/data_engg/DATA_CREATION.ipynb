# %%
import sys,os

ENV = 'mac'
if ENV == 'colab':
    base_path = "/content/drive/Othercomputers/My Mac/"
    project_path = "/content/drive/Othercomputers/My Mac/Documents/trading/"
else:
    base_path = "/Volumes/Seagate/"
    project_path = "/Users/prabhatkumar/Documents/trading/"
sys.path.append(project_path)    
import qml.data.utils.duckdb_utils as ddu
import duckdb
import qml.data.utils.data_utils as du

# %%
duckdb.__version__
# Out:
# '0.5.1'

# %%
url = 'https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files'
ext = '0.4.0-oneiric1_amd64.deb -qO'
# !wget $url/libta-lib0_$ext libta.deb
# !wget $url/ta-lib0-dev_$ext ta.deb
# !dpkg -i libta.deb ta.deb
# !pip install ta-lib
# Out:
# Selecting previously unselected package libta-lib0.
# (Reading database ... 128276 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# Selecting previously unselected package ta-lib0-dev.
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta-lib
#   Downloading TA-Lib-0.4.25.tar.gz (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.0/272.0 KB 13.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from ta-lib) (1.22.4)
# Building wheels for collected packages: ta-lib
#   Building wheel for ta-lib (pyproject.toml) ... done
#   Created wheel for ta-lib: filename=TA_Lib-0.4.25-cp39-cp39-linux_x86_64.whl size=2261331 sha256=2fe7c605e172c77559ef41c9c24d2dc6f7bd949c86108051ffb5e642672ec290
#   Stored in directory: /root/.cache/pip/wheels/a4/1e/ce/8f22bc445ab10758bc4e6babe45f688e199d3a1c6e7d28d32e
# Successfully built ta-lib
# Installing collected packages: ta-lib
# Successfully installed ta-lib-0.4.25

# %%
# !pip install duckdb==0.5.1
# !pip install hydra-core
# !pip install TA-Lib-binary
# !pip install -U git+https://github.com/twopirllc/pandas-ta
# !pip install feature_engine
# !pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting duckdb==0.5.1
#   Downloading duckdb-0.5.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.9/dist-packages (from duckdb==0.5.1) (1.22.4)
# Installing collected packages: duckdb
# Successfully installed duckdb-0.5.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hydra-core
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 KB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from hydra-core) (23.0)
# Collecting omegaconf<2.4,>=2.2
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 11.0 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 14.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.9/dist-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=534e67bffb6a1954f1be8b2c0b213e4d9ae12b49ccc6cb6baecc1289d3ea3ba6
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf, hydra-core
# Successfully installed antlr4-python3-runtime-4.9.3 hydra-core-1.3.2 omegaconf-2.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement TA-Lib-binary (from versions: none)
# ERROR: No matching distribution found for TA-Lib-binary
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/twopirllc/pandas-ta
#   Cloning https://github.com/twopirllc/pandas-ta to /tmp/pip-req-build-b4nb1knc
#   Running command git clone --filter=blob:none --quiet https://github.com/twopirllc/pandas-ta /tmp/pip-req-build-b4nb1knc
#   Resolved https://github.com/twopirllc/pandas-ta to commit 084dbe1c4b76082f383fa3029270ea9ac35e4dc7
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from pandas-ta==0.3.14b0) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandas-ta==0.3.14b0) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->pandas-ta==0.3.14b0) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->pandas-ta==0.3.14b0) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->pandas-ta==0.3.14b0) (1.15.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=219769 sha256=9da286c11b611801d938fe0f3676d1edf9075ceff3e20f2ae354576f0db7f59a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jnrb1y1o/wheels/20/45/7a/52ed064b376efce7aac331bdf6a48e0bb6a22f91ce864810d6
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feature_engine
#   Downloading feature_engine-1.5.2-py2.py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 KB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.10.1)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (0.13.5)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.2.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.4.4)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.9/dist-packages (from feature_engine) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature_engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.3->feature_engine) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature_engine) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=1.0.0->feature_engine) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature_engine) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from statsmodels>=0.11.1->feature_engine) (23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature_engine) (1.15.0)
# Installing collected packages: feature_engine
# Successfully installed feature_engine-1.5.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from ta) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ta) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ta) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29103 sha256=f573f0863d5af943c7d70a8e472a7c4e7749334e646628fdef30c39712b7c00a
#   Stored in directory: /root/.cache/pip/wheels/6a/76/03/7f785aaa50b9c6ec7e3fd105a62c1b2c45a034512d51e024a9
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %% [markdown]
# ## Define pipeline parameters

# %%
master_config_path = "../../../nifty/config/"
master_config_name = 'master_v1'
data_suffix = 'v1'
schema = 'nifty'

database_path = f"{base_path}google_drive/database/nifty.duckdb"
#db_connection = duckdb.connect(database=database_path , read_only=False)

train_feature_table = f'{schema}.train_feature_{data_suffix}'
train_feature_info_table = f'{schema}.train_feature_info_{data_suffix}'
train_feature_selection_table = f'{schema}.train_feature_selection_{data_suffix}'
train_training_info_table = f'{schema}.train_training_info_{data_suffix}'
train_tuning_info_table = f'{schema}.train_tuning_info_{data_suffix}'
ohlcraw_table = f'{schema}.ohlc_raw_data'

label_creation=False
techindicator1=False
techindicator2=False
techindicator3=False
time_splitter = False
column_unstable = False
update_unstable = False
load_tmp = True
#con = duckdb.connect(database=database_path , read_only=False)
filter_out_cols =["CMF_","RVGIs_","SSF_","STDEVALL","DPO_","ICS_","KAMA_","PDIST","RVGI_","PSAR","QS_"]

# %% [markdown]
# ## Create Data creation pipeline

# %%
obj = du.execute_data_pipeline(master_config_path, 
                               master_config_name, 
                               db_conection=None, 
                               database_path=database_path,
                               feature_spec_name=feature_spec_name,
                               train_feature_table=train_feature_table,
                               train_feature_info_table=train_feature_info_table,
                               techindicator1=techindicator1,
                               techindicator2=techindicator2,
                               techindicator3=techindicator3,
                               time_splitter = time_splitter,
                               column_unstable = column_unstable,
                               label_creation=label_creation,
                               update_unstable=update_unstable,
                               load_tmp = load_tmp)

# %%
obj.feature_pipeline.feature_mart.ticker_name
# Out:
# 'banknifty'

# %%
obj.run_pipelines()
# Out:
# Reject columns are :
# ['PSARl_0.02_0.2_psar1', 'PSARs_0.02_0.2_psar1', 'PSARaf_0.02_0.2_psar1', 'PSARr_0.02_0.2_psar1', 'PSARl_0.02_0.2_psar2', 'PSARs_0.02_0.2_psar2', 'PSARaf_0.02_0.2_psar2', 'PSARr_0.02_0.2_psar2', 'PSARl_0.02_0.2_psar3', 'PSARs_0.02_0.2_psar3', 'PSARaf_0.02_0.2_psar3', 'PSARr_0.02_0.2_psar3', 'PSARl_0.02_0.2_psar4', 'PSARs_0.02_0.2_psar4', 'PSARaf_0.02_0.2_psar4', 'PSARr_0.02_0.2_psar4', 'PSARl_0.02_0.2_psar5', 'PSARs_0.02_0.2_psar5', 'PSARaf_0.02_0.2_psar5', 'PSARr_0.02_0.2_psar5', 'PSARl_0.02_0.2_psar6', 'PSARs_0.02_0.2_psar6', 'PSARaf_0.02_0.2_psar6', 'PSARr_0.02_0.2_psar6', 'SUPERT_15_3.0_supertrend_close', 'SUPERTd_15_3.0_supertrend_close', 'SUPERTl_15_3.0_supertrend_close', 'SUPERTs_15_3.0_supertrend_close', 'SUPERT_30_3.0_supertrend_close', 'SUPERTd_30_3.0_supertrend_close', 'SUPERTl_30_3.0_supertrend_close', 'SUPERTs_30_3.0_supertrend_close', 'SUPERT_45_3.0_supertrend_close', 'SUPERTd_45_3.0_supertrend_close', 'SUPERTl_45_3.0_supertrend_close', 'SUPERTs_45_3.0_supertrend_close', 'SUPERT_60_3.0_supertrend_close', 'SUPERTd_60_3.0_supertrend_close', 'SUPERTl_60_3.0_supertrend_close', 'SUPERTs_60_3.0_supertrend_close', 'SUPERT_120_3.0_supertrend_close', 'SUPERTd_120_3.0_supertrend_close', 'SUPERTl_120_3.0_supertrend_close', 'SUPERTs_120_3.0_supertrend_close', 'SUPERT_240_3.0_supertrend_close', 'SUPERTd_240_3.0_supertrend_close', 'SUPERTl_240_3.0_supertrend_close', 'SUPERTs_240_3.0_supertrend_close', 'SUPERT_15_3.0_supertrend_close10', 'SUPERTd_15_3.0_supertrend_close10', 'SUPERTl_15_3.0_supertrend_close10', 'SUPERTs_15_3.0_supertrend_close10', 'SUPERT_30_3.0_supertrend_close10', 'SUPERTd_30_3.0_supertrend_close10', 'SUPERTl_30_3.0_supertrend_close10', 'SUPERTs_30_3.0_supertrend_close10', 'SUPERT_45_3.0_supertrend_close10', 'SUPERTd_45_3.0_supertrend_close10', 'SUPERTl_45_3.0_supertrend_close10', 'SUPERTs_45_3.0_supertrend_close10', 'SUPERT_60_3.0_supertrend_close10', 'SUPERTd_60_3.0_supertrend_close10', 'SUPERTl_60_3.0_supertrend_close10', 'SUPERTs_60_3.0_supertrend_close10', 'SUPERT_120_3.0_supertrend_close10', 'SUPERTd_120_3.0_supertrend_close10', 'SUPERTl_120_3.0_supertrend_close10', 'SUPERTs_120_3.0_supertrend_close10', 'SUPERT_240_3.0_supertrend_close10', 'SUPERTd_240_3.0_supertrend_close10', 'SUPERTl_240_3.0_supertrend_close10', 'SUPERTs_240_3.0_supertrend_close10', 'SUPERT_15_3.0_supertrend_close20', 'SUPERTd_15_3.0_supertrend_close20', 'SUPERTl_15_3.0_supertrend_close20', 'SUPERTs_15_3.0_supertrend_close20', 'SUPERT_30_3.0_supertrend_close20', 'SUPERTd_30_3.0_supertrend_close20', 'SUPERTl_30_3.0_supertrend_close20', 'SUPERTs_30_3.0_supertrend_close20', 'SUPERT_45_3.0_supertrend_close20', 'SUPERTd_45_3.0_supertrend_close20', 'SUPERTl_45_3.0_supertrend_close20', 'SUPERTs_45_3.0_supertrend_close20', 'SUPERT_60_3.0_supertrend_close20', 'SUPERTd_60_3.0_supertrend_close20', 'SUPERTl_60_3.0_supertrend_close20', 'SUPERTs_60_3.0_supertrend_close20', 'SUPERT_120_3.0_supertrend_close20', 'SUPERTd_120_3.0_supertrend_close20', 'SUPERTl_120_3.0_supertrend_close20', 'SUPERTs_120_3.0_supertrend_close20', 'SUPERT_240_3.0_supertrend_close20', 'SUPERTd_240_3.0_supertrend_close20', 'SUPERTl_240_3.0_supertrend_close20', 'SUPERTs_240_3.0_supertrend_close20', 'BBL_15_2.0_close', 'BBM_15_2.0_close', 'BBU_15_2.0_close', 'BBB_15_2.0_close', 'BBP_15_2.0_close', 'BBL_30_2.0_close', 'BBM_30_2.0_close', 'BBU_30_2.0_close', 'BBB_30_2.0_close', 'BBP_30_2.0_close', 'BBL_45_2.0_close', 'BBM_45_2.0_close', 'BBU_45_2.0_close', 'BBB_45_2.0_close', 'BBP_45_2.0_close', 'BBL_60_2.0_close', 'BBM_60_2.0_close', 'BBU_60_2.0_close', 'BBB_60_2.0_close', 'BBP_60_2.0_close', 'BBL_120_2.0_close', 'BBM_120_2.0_close', 'BBU_120_2.0_close', 'BBB_120_2.0_close', 'BBP_120_2.0_close', 'BBL_240_2.0_close', 'BBM_240_2.0_close', 'BBU_240_2.0_close', 'BBB_240_2.0_close', 'BBP_240_2.0_close', 'BBL_15_2.0_close10', 'BBM_15_2.0_close10', 'BBU_15_2.0_close10', 'BBB_15_2.0_close10', 'BBP_15_2.0_close10', 'BBL_30_2.0_close10', 'BBM_30_2.0_close10', 'BBU_30_2.0_close10', 'BBB_30_2 ...
# select sum(case when RSI_15_rsi_close is null then 1 else 0 end) RSI_15_rsi_close, sum(case when RSI_30_rsi_close is null then 1 else 0 end) RSI_30_rsi_close, sum(case when RSI_45_rsi_close is null then 1 else 0 end) RSI_45_rsi_close, sum(case when RSI_60_rsi_close is null then 1 else 0 end) RSI_60_rsi_close, sum(case when RSI_120_rsi_close is null then 1 else 0 end) RSI_120_rsi_close, sum(case when RSI_240_rsi_close is null then 1 else 0 end) RSI_240_rsi_close, sum(case when RSI_15_rsi_close10 is null then 1 else 0 end) RSI_15_rsi_close10, sum(case when RSI_30_rsi_close10 is null then 1 else 0 end) RSI_30_rsi_close10, sum(case when RSI_45_rsi_close10 is null then 1 else 0 end) RSI_45_rsi_close10, sum(case when RSI_60_rsi_close10 is null then 1 else 0 end) RSI_60_rsi_close10, sum(case when RSI_120_rsi_close10 is null then 1 else 0 end) RSI_120_rsi_close10, sum(case when RSI_240_rsi_close10 is null then 1 else 0 end) RSI_240_rsi_close10, sum(case when RSI_15_rsi_close20 is null then 1 else 0 end) RSI_15_rsi_close20, sum(case when RSI_30_rsi_close20 is null then 1 else 0 end) RSI_30_rsi_close20, sum(case when RSI_45_rsi_close20 is null then 1 else 0 end) RSI_45_rsi_close20, sum(case when RSI_60_rsi_close20 is null then 1 else 0 end) RSI_60_rsi_close20, sum(case when RSI_120_rsi_close20 is null then 1 else 0 end) RSI_120_rsi_close20, sum(case when RSI_240_rsi_close20 is null then 1 else 0 end) RSI_240_rsi_close20, sum(case when ADX_15_adx1 is null then 1 else 0 end) ADX_15_adx1, sum(case when DMP_15_adx1 is null then 1 else 0 end) DMP_15_adx1, sum(case when DMN_15_adx1 is null then 1 else 0 end) DMN_15_adx1, sum(case when ADX_30_adx2 is null then 1 else 0 end) ADX_30_adx2, sum(case when DMP_30_adx2 is null then 1 else 0 end) DMP_30_adx2, sum(case when DMN_30_adx2 is null then 1 else 0 end) DMN_30_adx2, sum(case when ADX_45_adx3 is null then 1 else 0 end) ADX_45_adx3, sum(case when DMP_45_adx3 is null then 1 else 0 end) DMP_45_adx3, sum(case when DMN_45_adx3 is null then 1 else 0 end) DMN_45_adx3, sum(case when ADX_60_adx4 is null then 1 else 0 end) ADX_60_adx4, sum(case when DMP_60_adx4 is null then 1 else 0 end) DMP_60_adx4, sum(case when DMN_60_adx4 is null then 1 else 0 end) DMN_60_adx4, sum(case when ADX_120_adx5 is null then 1 else 0 end) ADX_120_adx5, sum(case when DMP_120_adx5 is null then 1 else 0 end) DMP_120_adx5, sum(case when DMN_120_adx5 is null then 1 else 0 end) DMN_120_adx5, sum(case when ADX_240_adx6 is null then 1 else 0 end) ADX_240_adx6, sum(case when DMP_240_adx6 is null then 1 else 0 end) DMP_240_adx6, sum(case when DMN_240_adx6 is null then 1 else 0 end) DMN_240_adx6, sum(case when ADX_15_adx7 is null then 1 else 0 end) ADX_15_adx7, sum(case when DMP_15_adx7 is null then 1 else 0 end) DMP_15_adx7, sum(case when DMN_15_adx7 is null then 1 else 0 end) DMN_15_adx7, sum(case when ADX_30_adx8 is null then 1 else 0 end) ADX_30_adx8, sum(case when DMP_30_adx8 is null then 1 else 0 end) DMP_30_adx8, sum(case when DMN_30_adx8 is null then 1 else 0 end) DMN_30_adx8, sum(case when ADX_45_adx9 is null then 1 else 0 end) ADX_45_adx9, sum(case when DMP_45_adx9 is null then 1 else 0 end) DMP_45_adx9, sum(case when DMN_45_adx9 is null then 1 else 0 end) DMN_45_adx9, sum(case when ADX_60_adx10 is null then 1 else 0 end) ADX_60_adx10, sum(case when DMP_60_adx10 is null then 1 else 0 end) DMP_60_adx10, sum(case when DMN_60_adx10 is null then 1 else 0 end) DMN_60_adx10, sum(case when ADX_120_adx11 is null then 1 else 0 end) ADX_120_adx11, sum(case when DMP_120_adx11 is null then 1 else 0 end) DMP_120_adx11, sum(case when DMN_120_adx11 is null then 1 else 0 end) DMN_120_adx11, sum(case when ADX_240_adx12 is null then 1 else 0 end) ADX_240_adx12, sum(case when DMP_240_adx12 is null then 1 else 0 end) DMP_240_adx12, sum(case when DMN_240_adx12 is null then 1 else 0 end) DMN_240_adx12, sum(case when ADX_15_adx13 is null then 1 else 0 end) ADX_15_adx13, sum(case when DMP_15_adx13 is null then 1 else 0 end) DMP_15_adx13, sum(case wh ...
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_15_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.196037'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_15_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.240897'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.244847'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.247902'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.250257'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.251960'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.253388'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.255436'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_60_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.257284'
#                 WHERE feature_name = 'DIFFCOL_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.258764'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.260509'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.263081'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_close_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.265607'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.268193'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.270445'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.273330'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_15_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.275099'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.277789'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_30_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.279971'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_15_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.282123'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_15_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.284804'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_15_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.287060'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_15_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.289243'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.291127'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.293872'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.296001'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_30_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.297342'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.299207'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.301244'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.305013'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_0900_1030_close_60_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.307226'
#                 WHERE feature_name = 'DIFFCOL_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.308537'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.310762'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.313473'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_close_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.315511'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.317188'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1100_1200_close_15_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.319390'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.321442'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.322937'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_30_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_60_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.324845'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPDR_20_0_price_deviation_max_first_col_1200_0100_close_60_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_d_1_1min_close_60_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.326184'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_d_1_1min_close_60_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.328200'
#                 WHERE feature_name = 'DIFFCOL_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.329946'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.332051'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.333686'
#                 WHERE feature_name = 'ROLLPCM_DIFFCOL_ROLLPRH_0_w_1_1min_close_close_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.334981'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.336130'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.337950'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.339668'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_15_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.340976'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.342188'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.343205'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_30_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_60_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.344380'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_30_None_60_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_ROLLPCM_ROLLPRH_0_w_1_1min_close_60_None_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.345308'
#                 WHERE feature_name = 'DIFFCOL_ROLLPCM_ROLLPRH_0_w_1_1min_close_60_None_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_60_None_15_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.346371'
#                 WHERE feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_w_1_1min_close_60_None_15_None'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLPCM_ROLLPCM_ROLLPRH_0_d_1_1min_close_60_None_30_None',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
# ...
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLDIFF_0_0_super_diff21',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.500336'
#                 WHERE feature_name = 'ROLLDIFF_0_0_super_diff21'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLDIFF_0_0_super_diff16',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.502119'
#                 WHERE feature_name = 'ROLLDIFF_0_0_super_diff16'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLDIFF_0_0_super_diff5',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.504196'
#                 WHERE feature_name = 'ROLLDIFF_0_0_super_diff5'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_PSARl_002_02_psar5_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.506650'
#                 WHERE feature_name = 'DIFFCOL_PSARl_002_02_psar5_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_PSARl_002_02_psar6_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.508906'
#                 WHERE feature_name = 'DIFFCOL_PSARl_002_02_psar6_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_PSARl_002_02_psar4_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.510884'
#                 WHERE feature_name = 'DIFFCOL_PSARl_002_02_psar4_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_PSARl_002_02_psar3_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.512752'
#                 WHERE feature_name = 'DIFFCOL_PSARl_002_02_psar3_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_PSARl_002_02_psar2_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.514230'
#                 WHERE feature_name = 'DIFFCOL_PSARl_002_02_psar2_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_PSARl_002_02_psar1_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.516008'
#                 WHERE feature_name = 'DIFFCOL_PSARl_002_02_psar1_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_30_30_supertrend_close20_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.518856'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_30_30_supertrend_close20_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_30_30_supertrend_close10_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.523597'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_30_30_supertrend_close10_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_30_30_supertrend_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.525940'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_30_30_supertrend_close_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_45_30_supertrend_close20_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.527408'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_45_30_supertrend_close20_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_45_30_supertrend_close10_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.529591'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_45_30_supertrend_close10_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_45_30_supertrend_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.531951'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_45_30_supertrend_close_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_120_30_supertrend_close20_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.535062'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_120_30_supertrend_close20_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_60_30_supertrend_close20_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.537720'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_60_30_supertrend_close20_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_120_30_supertrend_close10_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.540086'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_120_30_supertrend_close10_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_60_30_supertrend_close10_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.543455'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_60_30_supertrend_close10_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_120_30_supertrend_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.545651'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_120_30_supertrend_close_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_60_30_supertrend_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.547759'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_60_30_supertrend_close_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'ROLLDIFF_0_0_super_diff11',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.550725'
#                 WHERE feature_name = 'ROLLDIFF_0_0_super_diff11'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_240_30_supertrend_close20_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.553515'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_240_30_supertrend_close20_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_240_30_supertrend_close10_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.555357'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_240_30_supertrend_close10_close'
#
# SQL to be run is
#                 UPDATE banknifty.train_feature_info_improved_one
#                 SET
#                 function_name = 'update_nulls',
#                 feature_name = 'DIFFCOL_SUPERTl_240_30_supertrend_close_close',
#                 max_date = '1999-01-01 09:00:00',
#                 min_date = '1999-01-01 09:00:00',
#                 status = 'saved',
#                 column_type = 'null_reject',
#                 feature_args = {'tolerance_count': 6000},
#                 updated_timestamp = '2023-03-21 04:55:28.557502'
#                 WHERE feature_name = 'DIFFCOL_SUPERTl_240_30_supertrend_close_close'
#
# Connection closed

# %%
'''
db_connection = duckdb.connect(database=database_path , read_only=False)

ddu.drop_object(connection=db_connection,object_type='table',object_name=train_feature_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_feature_info_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_feature_selection_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_training_info_table)
ddu.drop_object(connection=db_connection,object_type='table',object_name=train_tuning_info_table)
db_connection.close()
'''
# Out:
# DROP sql is DROP table IF EXISTS banknifty.train_feature_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_feature_info_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_feature_selection_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_training_info_improved_one
# DROP sql is DROP table IF EXISTS banknifty.train_tuning_info_improved_one

# %%
db_connection = duckdb.connect(database=database_path , read_only=False)

# %%
y = ddu.load_table_df(connection=db_connection,table_name=train_feature_info_table)
#y = y.sort_values(by='timestamp')
y.head()
# Out:
#    function_name                                       feature_name  \
# 0  label_creator  label__minus_15_1min_close__label_generator_4c...
# 1  label_creator  label__minus_30_1min_close__label_generator_4c...
# 2  label_creator  label__minus_45_1min_close__label_generator_4c...
# 3  label_creator  label__minus_60_1min_close__label_generator_4c...
# 4  label_creator  label__minus_15_1min_close__label_generator_4c...
#
#              max_date            min_date status column_type  \
# 0 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 1 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 2 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 3 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
# 4 2022-12-23 15:32:00 2010-03-02 09:01:00  saved       label
#
#                                         feature_args  \
# 0  {'freq': 1min, 'shift': -15, 'shift_column': c...
# 1  {'freq': 1min, 'shift': -30, 'shift_column': c...
# 2  {'freq': 1min, 'shift': -45, 'shift_column': c...
# 3  {'freq': 1min, 'shift': -60, 'shift_column': c...
# 4  {'freq': 1min, 'shift': -15, 'shift_column': c...
#
#            updated_timestamp
# 0 2023-03-19 11:28:51.064746
# 1 2023-03-19 11:28:57.786420
# 2 2023-03-19 11:29:04.771801
# 3 2023-03-19 11:29:11.719954
# 4 2023-03-19 11:29:18.623249

# %%
y['column_type'].value_counts()
# Out:
# feature            1645
# unstable_column     292
# null_reject         166
# label                16
# ohlc_column           4
# splittercolumn        1
# Name: column_type, dtype: int64

# %%
con.close()
